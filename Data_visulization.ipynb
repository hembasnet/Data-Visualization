# %% [markdown]
# <a href="https://colab.research.google.com/github/hembasnet/Data-Visualization/blob/main/Data_visulization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

import pandas as pd

#load data set
data = pd.read_csv('/content/Live (2).csv')
display(data.head(10))
# Out:
#                           status_id status_type status_published  \
# 0  246675545449582_1649696485147474       video   4/22/2018 6:00
# 1  246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2  246675545449582_1648730588577397       video   4/21/2018 6:17
# 3  246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4  246675545449582_1645700502213739       photo   4/18/2018 3:22
# 5  246675545449582_1645650162218773       photo   4/18/2018 2:14
# 6  246675545449582_1645564175560705       video   4/18/2018 0:24
# 7  246675545449582_1644824665634656       video   4/17/2018 7:42
# 8  246675545449582_1644655795651543       photo   4/17/2018 3:33
# 9  246675545449582_1638788379571618       photo   4/11/2018 4:53
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# ...

# %%
style.use("ggplot")

# Convert 'status_published' to datetime objects
data['status_published'] = pd.to_datetime(data['status_published'])

# Group by date and status type and count occurrences
status_counts = data.groupby([data['status_published'].dt.date, 'status_type']).size().unstack(fill_value=0)

# Plot the counts for each status type over time
status_counts.plot(figsize=(12, 6))

plt.xlabel('Date of Publication')
plt.ylabel('Number of Posts')
plt.title('Number of Posts by Status Type Over Time')
plt.legend(title='Status Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's visualize the distribution of 'num_likes' using a histogram.

# %%
style.use("ggplot")

plt.figure(figsize=(10, 6))
plt.hist(data['num_likes'], bins=50, color='skyblue', edgecolor='black')
plt.xlabel('Number of Likes')
plt.ylabel('Frequency')
plt.title('Distribution of Number of Likes')
plt.tight_layout()
plt.show()
